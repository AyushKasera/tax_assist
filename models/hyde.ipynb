# %%
from langchain_core.output_parsers import StrOutputParser
from langchain_core.prompts import ChatPromptTemplate
from langchain_huggingface import HuggingFaceEmbeddings, HuggingFaceEndpoint

# %%
prompt = ChatPromptTemplate.from_messages(
  [
    (
      """
      You are amazing and have a decent knowledge on indian taxation system.\
        provide the hypothetical answer to every question asked by user 
**User Query:**  
{query}  
"""
    )
  ]
)

# %%
import os
HF_TOKEN = os.environ.get("HF_TOKEN")
huggingface_repo_id = "mistralai/Mistral-7B-Instruct-v0.3"

def load_llm(huggingface_repo_id):
    llm = HuggingFaceEndpoint(
      repo_id=huggingface_repo_id,
      temperature=0.5,
      model_kwargs={"token":HF_TOKEN,
                    "max_length":"512"}
    )
    return llm

# %%
from langchain_community.llms import Ollama
llm = Ollama(model="llama3.1")
# Out:
# C:\Users\uadit\AppData\Local\Temp\ipykernel_14468\3956991393.py:2: LangChainDeprecationWarning: The class `Ollama` was deprecated in LangChain 0.3.1 and will be removed in 1.0.0. An updated version of the class exists in the :class:`~langchain-ollama package and should be used instead. To use it run `pip install -U :class:`~langchain-ollama` and import as `from :class:`~langchain_ollama import OllamaLLM``.
#   llm = Ollama(model="llama3.1")

# %%
hypothetical_ans = prompt |llm| StrOutputParser()

# %%
query = "what is 80c "
response = hypothetical_ans.invoke({"query":query})
response
# Out:
# "A classic one!\n\nIn the Indian taxation system, Section 80C of the Income Tax Act, 1961, allows individuals to claim deductions from their taxable income up to a certain limit. This section provides for tax deductions on various investments and expenses made by an individual or his family during the financial year.\n\nLet's assume that Rohan invests ₹2 lakhs in his PPF account (Public Provident Fund), which is eligible for deduction under Section 80C. His taxable income is ₹8 lakhs, and he has already invested ₹1 lakh in a tax-free bond. The remaining investment of ₹1 lakh is eligible for deduction under Section 80C.\n\nHere's the breakdown:\n\n* Total investments: ₹2 lakhs (PPF)\n* Deduction limit under Section 80C: ₹1.5 lakhs\n* Unused deductions: ₹0.5 lakhs\n\nIn this hypothetical scenario, Rohan can claim a tax deduction of ₹1 lakh under Section 80C for the PPF investment.\n\nNow, let me know if you'd like to ask another question!"
